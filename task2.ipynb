# %% [markdown]
# <a href="https://colab.research.google.com/github/RajKumarkpy/LGMVIP-DATASCIENCE/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  New Section

# %% [markdown]
# # **Lets Grow More**
#
# **Task 2**
#
# **Name :Rajkumar.s **
#
#
#
# **Data Science Internship**
#
#
#
# **Image to Pencil Sketch with Python**
#
# **Description Of Task :**We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# Read the image

# %%
cat_image = cv2.imread("cat.jpg")
plt.figure(figsize=(8,8))
plt.imshow(cat_image)
plt.show()

# %%
rg_img = cv2.cvtColor(cat_image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,8))
plt.imshow(rg_img)
plt.show()

# %%
gray_img = cv2.cvtColor(rg_img, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8,8))
plt.imshow(gray_img,cmap='gray')
plt.show()

# %%
invert_grayimg =255 - grayimg
plt.figure(figsize=(8,8))
plt.imshow(invert_grayimg,cmap='gray')
plt.show()

# %%
blur_img = cv2.GaussianBlur(invert_grayimg, (21,21), 0)
plt.figure(figsize=(8,8))
plt.imshow(blur_img,cmap='gray')
plt.show()

# %%
invert_blurimg = 255 - blur_img
plt.figure(figsize=(8,8))
plt.imshow(invert_blurimg,cmap='gray')
plt.show()

# %% [markdown]
# **Now for the final touch divide the grayscale image with inverted blurred image**

# %%
sketch_img = cv2.divide(gray_img, invert_blurimg, scale=256.0)


plt.figure(figsize=(8,8))
plt.imshow(sketch_img,cmap='gray')
plt.show()
